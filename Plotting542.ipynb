# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
ddata = pd.read_table("Downloads/retada/gaussiangen.csv")

# %%
ddata.head()
# Out:
#    TupleID  DBSCANID  KmeansID  GeneratedID       x      y
# 0        1         1         1            3   6.807  0.715
# 1        2         3         5            4  14.198 -6.896
# 2        3         2         2            2  -3.719 -1.096
# 3        4         0         4            5   8.955 -5.494
# 4        5         2         2            2  -2.418 -1.614

# %%
x0=list(ddata[ddata.DBSCANID == 0]['x'])
y0=list(ddata[ddata.DBSCANID == 0]['y'])
x1=list(ddata[ddata.DBSCANID == 1]['x'])
y1=list(ddata[ddata.DBSCANID == 1]['y'])
x2=list(ddata[ddata.DBSCANID == 2]['x'])
y2=list(ddata[ddata.DBSCANID == 2]['y'])
x3=list(ddata[ddata.DBSCANID == 3]['x'])
y3=list(ddata[ddata.DBSCANID == 3]['y'])
x4=list(ddata[ddata.DBSCANID == 4]['x'])
y4=list(ddata[ddata.DBSCANID == 4]['y'])
x5=list(ddata[ddata.DBSCANID == 5]['x'])
y5=list(ddata[ddata.DBSCANID == 5]['y'])

colors = np.random.rand(50)
# area = np.pi * (15 * np.random.rand(50))**2  # 0 to 15 point radiuses

plt.scatter(x1, y1,color='blue', alpha=0.5)
plt.scatter(x2, y2, color='red', alpha=0.5)
plt.scatter(x3,y3,color='green',alpha=0.5)
plt.scatter(x4,y4,color='yellow',alpha=0.5)
plt.scatter(x5,y5,color='black',alpha=0.5)
plt.scatter(x0,y0,color='cyan',alpha=0.5)
plt.show()

# %%
x0=list(ddata[ddata.KmeansID == 0]['x'])
y0=list(ddata[ddata.KmeansID == 0]['y'])
x1=list(ddata[ddata.KmeansID == 1]['x'])
y1=list(ddata[ddata.KmeansID == 1]['y'])
x2=list(ddata[ddata.KmeansID == 2]['x'])
y2=list(ddata[ddata.KmeansID == 2]['y'])
x3=list(ddata[ddata.KmeansID == 3]['x'])
y3=list(ddata[ddata.KmeansID == 3]['y'])
x4=list(ddata[ddata.KmeansID == 4]['x'])
y4=list(ddata[ddata.KmeansID == 4]['y'])
x5=list(ddata[ddata.KmeansID == 5]['x'])
y5=list(ddata[ddata.KmeansID == 5]['y'])

colors = np.random.rand(50)
# area = np.pi * (15 * np.random.rand(50))**2  # 0 to 15 point radiuses

plt.scatter(x1, y1,color='blue', alpha=0.5)
plt.scatter(x2, y2, color='red', alpha=0.5)
plt.scatter(x3,y3,color='green',alpha=0.5)
plt.scatter(x4,y4,color='yellow',alpha=0.5)
plt.scatter(x5,y5,color='black',alpha=0.5)
plt.scatter(x0,y0,color='cyan',alpha=0.5)
plt.show()

# %%
x0=list(ddata[ddata.GeneratedID == 0]['x'])
y0=list(ddata[ddata.GeneratedID == 0]['y'])
x1=list(ddata[ddata.GeneratedID == 1]['x'])
y1=list(ddata[ddata.GeneratedID == 1]['y'])
x2=list(ddata[ddata.GeneratedID == 2]['x'])
y2=list(ddata[ddata.GeneratedID == 2]['y'])
x3=list(ddata[ddata.GeneratedID == 3]['x'])
y3=list(ddata[ddata.GeneratedID == 3]['y'])
x4=list(ddata[ddata.GeneratedID == 4]['x'])
y4=list(ddata[ddata.GeneratedID == 4]['y'])
x5=list(ddata[ddata.GeneratedID == 5]['x'])
y5=list(ddata[ddata.GeneratedID == 5]['y'])

colors = np.random.rand(50)
# area = np.pi * (15 * np.random.rand(50))**2  # 0 to 15 point radiuses

plt.scatter(x1, y1,color='blue', alpha=0.5)
plt.scatter(x2, y2, color='red', alpha=0.5)
plt.scatter(x3,y3,color='green',alpha=0.5)
plt.scatter(x4,y4,color='yellow',alpha=0.5)
plt.scatter(x5,y5,color='black',alpha=0.5)
plt.scatter(x0,y0,color='cyan',alpha=0.5)
plt.show()

# %%
attrperf = pd.read_table("Downloads/retada/kmeans.attrperf", skiprows=1)

# %%
attrperf.head()
# Out:
#    AttrCount  Repeats    Time(ns)  TimePerRep(ns)  Mem(bytes)
# 0          1       12  1043598630        86966553       40288
# 1          2       19  1049003963        55210735       40368
# 2          3       20  1040886442        52044322       40448
# 3          4       10  1027516179       102751618       40528
# 4          5       11  1173291766       106662888       40608

# %%
plt.plot(attrperf[attrperf.columns[0]],attrperf[attrperf.columns[2]],color='red')
plt.plot(attrperf[attrperf.columns[0]],attrperf[attrperf.columns[3]],color='green')
plt.plot(attrperf[attrperf.columns[0]],attrperf[attrperf.columns[4]],color='blue')
plt.show()

# %%
plt.plot(attrperf[attrperf.columns[0]],attrperf[attrperf.columns[4]],color='blue')
plt.show()

# %%
clusterpref = pd.read_table("Downloads/retada/kmeans.clusperf", skiprows=1)

# %%
clusterpref.head()
# Out:
#    ClusterCount  Repeats    Time(ns)  TimePerRep(ns)  Mem(bytes)
# 0             1     1368  1000120761          731082       40200
# 1             2      178  1004253091         5641871       40232
# 2             3       82  1017068264        12403272       40272
# 3             4       49  1011532862        20643528       40304
# 4             5       16  1034384760        64649048       40344

# %%
plt.plot(clusterpref[clusterpref.columns[0]],clusterpref[clusterpref.columns[2]],color='red')
plt.plot(clusterpref[clusterpref.columns[0]],clusterpref[clusterpref.columns[3]],color='green')
# plt.plot(clusterpref[clusterpref.columns[0]],clusterpref[clusterpref.columns[4]],color='blue')
plt.show()

# %%
plt.plot(clusterpref[clusterpref.columns[0]],clusterpref[clusterpref.columns[4]],color='blue')
plt.show()

# %%
tuplepref= pd.read_table("Downloads/retada/kmeans.tupleperf", skiprows=1)

# %%
tuplepref.head()
# Out:
#    TupleCount  Repeats      Time(ns)  TimePerRep(ns)  Mem(bytes)
# 0         100   3927.0  1.000116e+09        254677.0       928.0
# 1         120   4497.0  1.000042e+09        222380.0      1008.0
# 2         144   3232.0  1.000027e+09        309414.0      1104.0
# 3         173      NaN           NaN             NaN         NaN

# %%
plt.plot(tuplepref[tuplepref.columns[0]],tuplepref[tuplepref.columns[2]],color='red')
plt.plot(tuplepref[tuplepref.columns[0]],tuplepref[tuplepref.columns[3]],color='green')
plt.show()

# %%
quality= pd.read_table("Downloads/retada/kmeans.quality", skiprows=1)

# %%
quality.head()
# Out:
#    AttrCount  TupleCount  ClusterCount  B3Precision  B3Recall  Silhouette
# 0          1         100             1      0.68909       1.0         0.0
# 1          1         150             1      0.66989       1.0         0.0
# 2          1         225             1      0.66802       1.0         0.0
# 3          1         338             1      0.67763       1.0         0.0
# 4          1         507             1      0.66862       1.0         0.0

# %%
x6=list(quality[quality.AttrCount == 6]['TupleCount'])
y6=list(quality[quality.AttrCount == 6]['B3Precision'])
x1=list(quality[quality.AttrCount == 1]['TupleCount'])
y1=list(quality[quality.AttrCount == 1]['B3Precision'])
x2=list(quality[quality.AttrCount == 2]['TupleCount'])
y2=list(quality[quality.AttrCount == 2]['B3Precision'])
x3=list(quality[quality.AttrCount == 3]['TupleCount'])
y3=list(quality[quality.AttrCount == 3]['B3Precision'])
x4=list(quality[quality.AttrCount == 4]['TupleCount'])
y4=list(quality[quality.AttrCount == 4]['B3Precision'])
x5=list(quality[quality.AttrCount == 5]['TupleCount'])
y5=list(quality[quality.AttrCount == 5]['B3Precision'])

plt.plot(x1, y1, alpha=0.5)
# plt.plot(x2, y2, color='red', alpha=0.5)
# plt.plot(x3,y3,color='green',alpha=0.5)
# plt.plot(x4,y4,color='yellow',alpha=0.5)
# plt.plot(x5,y5,color='black',alpha=0.5)
# plt.plot(x6,y6,color='cyan',alpha=0.5)
plt.show()

# %%
len(y1)
# Out:
# 90
